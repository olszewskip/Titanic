# %% [markdown]
# # Goal:
#
# * Fit the training-data to a few classifiers.
# * Measure/visualize the performance using confusion matric and ROC-curve.
# * Choose the best model (possibly an ensamble) based on accuracy on the validation-data.
# * Save it to file.
#
# Note: the intermediate models are also saved to file, so that one may load them in instead of fitting below.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB, ComplementNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.pipeline import Pipeline

from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score
from sklearn.metrics import roc_curve, precision_recall_curve
import seaborn as sns

from pickle import dump, load

# %% [markdown]
# ---
# Copy-paste the data loading and the train-val-test split from the *preprocess_visualize.ipynb* notebook.

# %%
data_trainval = pd.read_csv(os.path.join('data', 'train.csv'))
X_trainval = data_trainval[data_trainval.columns.drop('Survived')]
y_trainval = data_trainval.Survived

X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.2, stratify = y_trainval, random_state=42)

# %%
X_val.shape
# Out:
# (179, 11)

# %%
y_val.value_counts() / len(y_val)
# Out:
# 0    0.614525
# 1    0.385475
# Name: Survived, dtype: float64

# %% [markdown]
# ---
# Define plotting utilities

# %%
def make_confusion_matrix(name, estimator, X_train=X_train, X_val=X_val, y_train=y_train, y_val=y_val):

    y_train_pred = estimator.predict(X_train)
    y_val_pred = estimator.predict(X_val)
    
    print(f"{name}:")
    print(f"Accuracy on train: {accuracy_score(y_train, y_train_pred):>20}")
    print(f"Accuracy on validation: {accuracy_score(y_val, y_val_pred):>20}")

    fig, axes = plt.subplots(1, 2)
    fig.set_size_inches(12,4)
    
    cm_train = confusion_matrix(y_train, y_train_pred)
    cm_train = cm_train.astype('float') / cm_train.sum(axis=1)[:, np.newaxis]
    sns.heatmap(cm_train, ax=axes[0], annot=True, cmap="YlGnBu")
    axes[0].set_xlabel('Predicted', fontsize=14)
    axes[0].set_ylabel('True', fontsize=14)
    axes[0].set_title(f'Confusion matrix on train', fontsize=15)
    
    cm_val = confusion_matrix(y_val, y_val_pred)
    cm_val = cm_val.astype('float') / cm_val.sum(axis=1)[:, np.newaxis]
    sns.heatmap(cm_val, ax=axes[1], annot=True, cmap="YlGnBu")
    axes[1].set_xlabel('Predicted', fontsize=14)
    axes[1].set_ylabel('True', fontsize=14)
    axes[1].set_title(f'Confusion matrix on validation', fontsize=15)
    
    plt.show()

    
def make_ROC(estimators, X_train=X_train, X_val=X_val, y_train=y_train, y_val=y_val):
    
    fig, axes = plt.subplots(1, 2)
    fig.set_size_inches(12, 5)
    
    for name, estimator in estimators.items():
        y_train_proba = estimator.predict_proba(X_train)[:,1]    
        fpr, tpr, thresholds = roc_curve(y_train, y_train_proba)
        axes[0].plot(fpr, tpr, label=name)

    axes[0].plot([0, 1], [0, 1], ls='--', color='black', lw=.3)
    axes[0].set(xlabel='False Positive Rate',
                ylabel='True Positive Rate',
                xlim=[-.01, 1.01], ylim=[-.01, 1.01],
                title='ROC curve on train')
    axes[0].grid(True)
    axes[0].legend()
    
    
    for name, estimator in estimators.items():
        y_val_proba = estimator.predict_proba(X_val)[:,1]    
        fpr, tpr, thresholds = roc_curve(y_val, y_val_proba)
        axes[1].plot(fpr, tpr, label=name)

    axes[1].plot([0, 1], [0, 1], ls='--', color='black', lw=.3)
    axes[1].set(xlabel='False Positive Rate',
              ylabel='True Positive Rate',
              xlim=[-.01, 1.01], ylim=[-.01, 1.01],
              title='ROC curve on validation')
    axes[1].grid(True)
    axes[1].legend()
    
    plt.show()

# %% [markdown]
# ---
# Build the preprocessing pipeline by running the script. It contains only class definitions and class instantiations (and occasional definition of a constant).

# %%
# %run build_preprocess_pipe.py

# %% [markdown]
# We can do e.g.

# %%
preprocess = preprocess_pipe(age_tresholds=[2, 5], fare_range=(0,1), k_features=0, n_components=-1).fit(X_train, y_train)

# %% [markdown]
# ---
# As a warmup, fit a few classifiers without tuning anything. We need models that can give a probability estimate. This rules out SVM-based classifiers.

# %%
X_train_preprocess = preprocess.transform(X_train)
X_val_preprocess = preprocess.transform(X_val)

# %%
neighbors = KNeighborsClassifier(n_neighbors=5).fit(X_train_preprocess, y_train)
print(neighbors.score(X_train_preprocess, y_train))
print(neighbors.score(X_val_preprocess, y_val))
# Out:
# 0.8539325842696629
# 0.7877094972067039

# %%
log_reg = LogisticRegression(random_state=123, solver = 'lbfgs').fit(X_train_preprocess, y_train)
print(log_reg.score(X_train_preprocess, y_train))
print(log_reg.score(X_val_preprocess, y_val))
# Out:
# 0.8370786516853933
# 0.8212290502793296

# %%
bayes_gauss = GaussianNB().fit(X_train_preprocess, y_train)
print(bayes_gauss.score(X_train_preprocess, y_train))
print(bayes_gauss.score(X_val_preprocess, y_val))
# Out:
# 0.7794943820224719
# 0.7150837988826816

# %%
bayes_complement = ComplementNB().fit(X_train_preprocess, y_train)
print(bayes_complement.score(X_train_preprocess, y_train))
print(bayes_complement.score(X_val_preprocess, y_val))
# Out:
# 0.7949438202247191
# 0.7597765363128491

# %%
rand_forest = RandomForestClassifier(n_estimators=150, max_depth=6, random_state=123).fit(X_train_preprocess, y_train)
print(rand_forest.score(X_train_preprocess, y_train))
print(rand_forest.score(X_val_preprocess, y_val))
# Out:
# 0.8876404494382022
# 0.7988826815642458

# %%
grad_boost = GradientBoostingClassifier(n_estimators=150, max_depth=3, random_state=123, learning_rate=0.1, subsample=0.9).fit(X_train_preprocess, y_train)
print(grad_boost.score(X_train_preprocess, y_train))
print(grad_boost.score(X_val_preprocess, y_val))
# Out:
# 0.925561797752809
# 0.7932960893854749

# %%
ada_boost = AdaBoostClassifier(base_estimator=ComplementNB(), n_estimators=150, learning_rate=0.5, random_state=123).fit(X_train_preprocess, y_train)
print(ada_boost.score(X_train_preprocess, y_train))
print(ada_boost.score(X_val_preprocess, y_val))
# Out:
# 0.8216292134831461
# 0.8212290502793296

# %% [markdown]
# Surprisingly, bare KNeighborsClassifier is not far behind. The naive Bayes's struggle, unless Ada-boosted. GradientBoosted trees are easy to overfit, wheras Logistic Regression seems rather robust in that regard. Let's choose KNeighbors, Logistic Regression, GradientBoosted trees and AdaBoosted Complement NaiveBayes for futher tuning.

# %% [markdown]
# ---
# ## GridSearch: K Nearest Neigbors

# %%
kneigh_clf = Pipeline([
    ('preprocess', preprocess_pipe()),
    ('clf', KNeighborsClassifier())
])

param_grid = {}
param_grid['preprocess__transform__numerical_transformer__fare_transformer__scaler__feature_range'] = [(-0.3, 1.3), (0, 1), (0.3, 0.7)]
param_grid['preprocess__transform__numerical_transformer__age_discretizer__tresholds'] = [[2, 5],[2, 5, 12, 50]]
param_grid['preprocess__feature_select__k_features'] = [6, 12]
param_grid['preprocess__pca__n_components'] = [12, 20]
param_grid['clf__n_neighbors'] = [3, 7]
param_grid['clf__weights'] = ['uniform', 'distance']
param_grid['clf__p'] = [1, 1.5, 2]

kneigh_clf_cv = GridSearchCV(kneigh_clf, param_grid, cv=4, refit=True, return_train_score=True, n_jobs=-1, iid=False).fit(X_train, y_train)

# %%
with open("kneigh_clf_cv.pkl", "wb") as file:
    dump(kneigh_clf_cv, file)

# %%
with open("kneigh_clf_cv.pkl", "rb") as file:
    kneigh_clf_cv = load(file)

# %% [markdown]
# Results of the Grid Search are given in the table below. One may choose which columns to display by specifying the corresponding number from the dictionary below.

# %%
column_translate = {key: idx for (idx, key) in enumerate(kneigh_clf_cv.cv_results_.keys())}
{idx: key for (idx, key) in enumerate(kneigh_clf_cv.cv_results_.keys())}
# Out:
# {0: 'mean_fit_time',
#  1: 'std_fit_time',
#  2: 'mean_score_time',
#  3: 'std_score_time',
#  4: 'param_clf__n_neighbors',
#  5: 'param_clf__p',
#  6: 'param_clf__weights',
#  7: 'param_preprocess__feature_select__k_features',
#  8: 'param_preprocess__pca__n_components',
#  9: 'param_preprocess__transform__numerical_transformer__age_discretizer__tresholds',
#  10: 'param_preprocess__transform__numerical_transformer__fare_transformer__scaler__feature_range',
#  11: 'params',
#  12: 'split0_test_score',
#  13: 'split1_test_score',
#  14: 'split2_test_score',
#  15: 'split3_test_score',
#  16: 'mean_test_score',
#  17: 'std_test_score',
#  18: 'rank_test_score',
#  19: 'split0_train_score',
#  20: 'split1_train_score',
#  21: 'split2_train_score',
#  22: 'split3_train_score',
#  23: 'mean_train_score',
#  24: 'std_train_score'}

# %%
choose = [4, 5, 6, 7, 8, 9, 10, 16, 23, 0]
sort_by = 16
results = pd.DataFrame(kneigh_clf_cv.cv_results_).iloc[:, choose].rename(columns=column_translate).sort_values(sort_by, ascending=False)
results.iloc[:10]
# Out:
#     4    5        6   7   8       9            10        16        23  \
# 254  7    2  uniform  12  12  [2, 5]   (0.3, 0.7)  0.824435  0.845028
# 162  7    1  uniform  12  20  [2, 5]  (-0.3, 1.3)  0.821611  0.844096
# 199  7  1.5  uniform   6  20  [2, 5]       (0, 1)  0.820237  0.837544
# 146  7    1  uniform   6  12  [2, 5]   (0.3, 0.7)  0.818833  0.838006
# 152  7    1  uniform   6  20  [2, 5]   (0.3, 0.7)  0.818825  0.843624
# 157  7    1  uniform  12  12  [2, 5]       (0, 1)  0.818794  0.840818
# 158  7    1  uniform  12  12  [2, 5]   (0.3, 0.7)  0.818786  0.840815
# 206  7  1.5  uniform  12  12  [2, 5]   (0.3, 0.7)  0.818770  0.842687
# 151  7    1  uniform   6  20  [2, 5]       (0, 1)  0.817436  0.842690
# 150  7    1  uniform   6  20  [2, 5]  (-0.3, 1.3)  0.817429  0.841753
#
#            0
# 254  0.157603
# 162  0.123631
# 199  0.154488
# 146  0.192455
# 152  0.209438
# 157  0.171615
# 158  0.158103
# 206  0.122047
# 151  0.204459
# 150  0.191253

# %%
make_confusion_matrix("K Nearest Neighbors", kneigh_clf_cv.best_estimator_)
# Out:
# K Nearest Neighbors:
# Accuracy on train:   0.8412921348314607
# Accuracy on validation:   0.7988826815642458

# %%
make_ROC({"K Nearest Neighbors": kneigh_clf_cv.best_estimator_})

# %% [markdown]
# ---
# ## GridSearch: Logistic Regression

# %%
logreg_clf = Pipeline([
    ('preprocess', preprocess_pipe()),
    ('clf', LogisticRegression(solver='saga', max_iter=1e5))
])

# %%
param_grid = {}
param_grid['preprocess__transform__numerical_transformer__fare_transformer__scaler__feature_range'] = [(-0.3, 1.3), (0, 1), (0.3, 0.7)]
param_grid['preprocess__transform__numerical_transformer__age_discretizer__tresholds'] = [[2, 5],[2, 5, 12, 50]]
param_grid['preprocess__feature_select__k_features'] = [6, 12]
param_grid['preprocess__pca__n_components'] = [12, 20]
param_grid['clf__C'] = [0.5, 0.75, 1, 2]
param_grid['clf__penalty'] = ['l1', 'l2']

logreg_clf_cv = GridSearchCV(logreg_clf, param_grid, cv=4, refit=True, return_train_score=True, n_jobs=-1, iid=False).fit(X_train, y_train)

# %%
with open("logreg_clf_cv.pkl", "wb") as file:
    dump(logreg_clf_cv, file)

# %%
with open("logreg_clf_cv.pkl", "rb") as file:
    logreg_clf_cv = load(file)

# %%
column_translate = {key: idx for (idx, key) in enumerate(logreg_clf_cv.cv_results_.keys())}
{idx: key for (idx, key) in enumerate(logreg_clf_cv.cv_results_.keys())}
# Out:
# {0: 'mean_fit_time',
#  1: 'std_fit_time',
#  2: 'mean_score_time',
#  3: 'std_score_time',
#  4: 'param_clf__C',
#  5: 'param_clf__penalty',
#  6: 'param_preprocess__feature_select__k_features',
#  7: 'param_preprocess__pca__n_components',
#  8: 'param_preprocess__transform__numerical_transformer__age_discretizer__tresholds',
#  9: 'param_preprocess__transform__numerical_transformer__fare_transformer__scaler__feature_range',
#  10: 'params',
#  11: 'split0_test_score',
#  12: 'split1_test_score',
#  13: 'split2_test_score',
#  14: 'split3_test_score',
#  15: 'mean_test_score',
#  16: 'std_test_score',
#  17: 'rank_test_score',
#  18: 'split0_train_score',
#  19: 'split1_train_score',
#  20: 'split2_train_score',
#  21: 'split3_train_score',
#  22: 'mean_train_score',
#  23: 'std_train_score'}

# %%
choose = [4, 5, 6, 7, 8, 9, 13, 20, 0]
sort_by = 13
results = pd.DataFrame(logreg_clf_cv.cv_results_).iloc[:, choose].rename(columns=column_translate).sort_values(sort_by, ascending=False)
results.iloc[:6]
# Out:
#     4   5  6   7               8            9         13        20        0
# 154  2  l1  6  20  [2, 5, 12, 50]       (0, 1)  0.831461  0.822097  0.245602
# 106  1  l1  6  20  [2, 5, 12, 50]       (0, 1)  0.825843  0.820225  0.232421
# 131  1  l2  6  20  [2, 5, 12, 50]   (0.3, 0.7)  0.825843  0.820225  0.245005
# 179  2  l2  6  20  [2, 5, 12, 50]   (0.3, 0.7)  0.825843  0.820225  0.256740
# 178  2  l2  6  20  [2, 5, 12, 50]       (0, 1)  0.825843  0.822097  0.277260
# 177  2  l2  6  20  [2, 5, 12, 50]  (-0.3, 1.3)  0.825843  0.823970  0.249830

# %%
make_confusion_matrix("Logistic Regression", logreg_clf_cv.best_estimator_)
# Out:
# Logistic Regression:
# Accuracy on train:   0.8314606741573034
# Accuracy on validation:   0.8212290502793296

# %%
make_ROC({"K Nearest Neighbors": kneigh_clf_cv.best_estimator_,
          "Logistic Regression": logreg_clf_cv.best_estimator_
         })

# %% [markdown]
# ---
# ## GridSearch: GradientBoosting

# %%
gradboost_clf = Pipeline([
    ('preprocess', preprocess_pipe()),
    ('clf', GradientBoostingClassifier(random_state=123))
])

param_grid = {}
param_grid['preprocess__transform__numerical_transformer__fare_transformer__scaler__feature_range'] = [(-0.3, 1.3), (0, 1), (0.3, 0.7)]
param_grid['preprocess__transform__numerical_transformer__age_discretizer__tresholds'] = [[2, 5],[2, 5, 12, 50]]
param_grid['preprocess__feature_select__k_features'] = [6, 12]
param_grid['preprocess__pca__n_components'] = [12, 20]
param_grid['clf__n_estimators'] = [100, 150]
param_grid['clf__max_depth'] = [3, 5]
param_grid['clf__learning_rate'] = [0.01, 0.1, 0.8]
param_grid['clf__subsample'] = [0.1, 0.5, 0.8]

gradboost_clf_cv = GridSearchCV(gradboost_clf, param_grid, cv=4, refit=True, return_train_score=True, n_jobs=-1, iid=False).fit(X_train, y_train)

# %%
with open("gradboost_clf_cv.pkl", "wb") as file:
    dump(gradboost_clf_cv, file)

# %%
with open("gradboost_clf_cv.pkl", "rb") as file:
    gradboost_clf_cv = load(file)

# %%
column_translate = {key: idx for (idx, key) in enumerate(gradboost_clf_cv.cv_results_.keys())}
{idx: key for (idx, key) in enumerate(gradboost_clf_cv.cv_results_.keys())}
# Out:
# {0: 'mean_fit_time',
#  1: 'std_fit_time',
#  2: 'mean_score_time',
#  3: 'std_score_time',
#  4: 'param_clf__learning_rate',
#  5: 'param_clf__max_depth',
#  6: 'param_clf__n_estimators',
#  7: 'param_clf__subsample',
#  8: 'param_preprocess__feature_select__k_features',
#  9: 'param_preprocess__pca__n_components',
#  10: 'param_preprocess__transform__numerical_transformer__age_discretizer__tresholds',
#  11: 'param_preprocess__transform__numerical_transformer__fare_transformer__scaler__feature_range',
#  12: 'params',
#  13: 'split0_test_score',
#  14: 'split1_test_score',
#  15: 'split2_test_score',
#  16: 'split3_test_score',
#  17: 'mean_test_score',
#  18: 'std_test_score',
#  19: 'rank_test_score',
#  20: 'split0_train_score',
#  21: 'split1_train_score',
#  22: 'split2_train_score',
#  23: 'split3_train_score',
#  24: 'mean_train_score',
#  25: 'std_train_score'}

# %%
choose = [4, 5, 6, 7, 8, 9, 10, 11, 17, 24, 0]
sort_by = 17
results = pd.DataFrame(gradboost_clf_cv.cv_results_).iloc[:, choose].rename(columns=column_translate).sort_values(sort_by, ascending=False)
results.iloc[:6]
# Out:
#        4  5    6    7  8   9               10           11        17  \
# 248  0.01  5  150  0.5  6  20          [2, 5]   (0.3, 0.7)  0.834259
# 273  0.01  5  150  0.8  6  20  [2, 5, 12, 50]  (-0.3, 1.3)  0.831474
# 247  0.01  5  150  0.5  6  20          [2, 5]       (0, 1)  0.831474
# 176  0.01  5  100  0.5  6  20          [2, 5]   (0.3, 0.7)  0.831442
# 127  0.01  3  150  0.8  6  20          [2, 5]       (0, 1)  0.831426
# 344   0.1  3  100  0.8  6  20          [2, 5]   (0.3, 0.7)  0.830117
#
#            24        0
# 248  0.925095  1.106374
# 273  0.932119  1.231475
# 247  0.925561  1.091004
# 176  0.911989  0.812735
# 127  0.882490  0.837419
# 344  0.945225  0.838980

# %%
make_confusion_matrix("Gradient Boosting", gradboost_clf_cv.best_estimator_)
# Out:
# Gradient Boosting:
# Accuracy on train:   0.9143258426966292
# Accuracy on validation:   0.7932960893854749

# %%
make_ROC({"K Nearest Neighbors": kneigh_clf_cv.best_estimator_,
          "Logistic Regression": logreg_clf_cv.best_estimator_,
          "Gradient Boosting": gradboost_clf_cv.best_estimator_
         })

# %% [markdown]
# ---
# ## GridSearch: AdaBoost + NaiveBayes

# %%
adaboost_clf = Pipeline([
    ('preprocess', preprocess_pipe()),
    ('clf', AdaBoostClassifier(base_estimator=ComplementNB(), random_state=123))
])

param_grid = {}
param_grid['preprocess__transform__numerical_transformer__fare_transformer__scaler__feature_range'] = [(0, 1), (0.3, 0.7)]
param_grid['preprocess__transform__numerical_transformer__age_discretizer__tresholds'] = [[2, 5],[2, 5, 12, 50]]
param_grid['preprocess__feature_select__k_features'] = [0, 8, 16]
param_grid['preprocess__pca__n_components'] = [-1]
param_grid['clf__n_estimators'] = [100, 150, 200]
param_grid['clf__learning_rate'] = [0.01,  0.1, 0.8]
param_grid['clf__base_estimator__alpha'] = [0.01, 0.1, 1]

adaboost_clf_cv = GridSearchCV(adaboost_clf, param_grid, cv=4, refit=True, return_train_score=True, n_jobs=-1, iid=False,).fit(X_train, y_train)

# %%
with open("adaboost_clf_cv.pkl", "wb") as file:
    dump(adaboost_clf_cv, file)

# %%
with open("adaboost_clf_cv.pkl", "rb") as file:
    adaboost_clf_cv = load(file)

# %%
column_translate = {key: idx for (idx, key) in enumerate(adaboost_clf_cv.cv_results_.keys())}
{idx: key for (idx, key) in enumerate(adaboost_clf_cv.cv_results_.keys())}
# Out:
# {0: 'mean_fit_time',
#  1: 'std_fit_time',
#  2: 'mean_score_time',
#  3: 'std_score_time',
#  4: 'param_clf__base_estimator__alpha',
#  5: 'param_clf__learning_rate',
#  6: 'param_clf__n_estimators',
#  7: 'param_preprocess__feature_select__k_features',
#  8: 'param_preprocess__pca__n_components',
#  9: 'param_preprocess__transform__numerical_transformer__age_discretizer__tresholds',
#  10: 'param_preprocess__transform__numerical_transformer__fare_transformer__scaler__feature_range',
#  11: 'params',
#  12: 'split0_test_score',
#  13: 'split1_test_score',
#  14: 'split2_test_score',
#  15: 'split3_test_score',
#  16: 'mean_test_score',
#  17: 'std_test_score',
#  18: 'rank_test_score',
#  19: 'split0_train_score',
#  20: 'split1_train_score',
#  21: 'split2_train_score',
#  22: 'split3_train_score',
#  23: 'mean_train_score',
#  24: 'std_train_score'}

# %%
choose = [4, 5, 6, 7, 9, 10, 16, 23, 0]
sort_by = 16
results = pd.DataFrame(adaboost_clf_cv.cv_results_).iloc[:, choose].rename(columns=column_translate).sort_values(sort_by, ascending=False)
results.iloc[:6]
# Out:
#       4    5    6  7               9           10        16        23  \
# 181  0.1  0.8  100  0          [2, 5]  (0.3, 0.7)  0.817437  0.835673
# 169  0.1  0.1  200  0          [2, 5]  (0.3, 0.7)  0.817429  0.834738
# 302    1  0.8  150  0  [2, 5, 12, 50]      (0, 1)  0.817428  0.837072
# 193  0.1  0.8  150  0          [2, 5]  (0.3, 0.7)  0.816032  0.835205
# 168  0.1  0.1  200  0          [2, 5]      (0, 1)  0.816024  0.834270
# 211  0.1  0.8  200  8  [2, 5, 12, 50]  (0.3, 0.7)  0.816024  0.838011
#
#            0
# 181  0.408346
# 169  0.812967
# 302  0.548965
# 193  0.703655
# 168  0.970238
# 211  0.775971

# %%
make_confusion_matrix("Ada Boosting", adaboost_clf_cv.best_estimator_)
# Out:
# Ada Boosting:
# Accuracy on train:   0.8370786516853933
# Accuracy on validation:   0.8156424581005587

# %%
make_ROC({"K Nearest Neighbors": kneigh_clf_cv.best_estimator_,
          "Logistic Regression": logreg_clf_cv.best_estimator_,
          "Gradient Boosting": gradboost_clf_cv.best_estimator_,
          "Ada Boosting": adaboost_clf_cv.best_estimator_
         })

# %% [markdown]
# ---
# ## Soft voting of the last three tuned classifiers

# %%
vote_clf = VotingClassifier([
                ("K Nearest Neighbors", kneigh_clf_cv.best_estimator_),
                ("Logistic Regression", logreg_clf_cv.best_estimator_),
                ("Gradient Boosting", gradboost_clf_cv.best_estimator_),
                ("Ada Boosting", adaboost_clf_cv.best_estimator_)
            ],
            voting="soft",
            weights = [1, 1, 1, 1]
            )

# %%
vote_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('K Nearest Neighbors', Pipeline(memory=None,
#      steps=[('preprocess', Pipeline(memory=None,
#      steps=[('transform', FeatureUnion(n_jobs=None,
#        transformer_list=[('numerical_transformer', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0,
#          transformer_..., fit_prior=True, norm=False),
#           learning_rate=0.8, n_estimators=100, random_state=123))]))],
#          flatten_transform=None, n_jobs=None, voting='soft',
#          weights=[1, 1, 1, 1])

# %%
make_confusion_matrix("Soft Voting", vote_clf)
# Out:
# Soft Voting:
# Accuracy on train:   0.8721910112359551
# Accuracy on validation:   0.8379888268156425

# %%
make_ROC({"K Nearest Neighbors": kneigh_clf_cv.best_estimator_,
          "Logistic Regression": logreg_clf_cv.best_estimator_,
          "Grad Boosting": gradboost_clf_cv.best_estimator_,
          "Ada Boosting": adaboost_clf_cv.best_estimator_,
          "Soft Voting": vote_clf
         })

# %% [markdown]
# Save the Voting Classifier to a file.

# %%
with open("vote_clf.pkl", "wb") as file:
    dump(vote_clf, file)

# %% [markdown]
# ---
# Example of some predicted probabilities...

# %%
print(vote_clf.predict_proba(X_val)[:5])

y_val[:5]
# Out:
# [[0.78720898 0.21279102]
#  [0.78960327 0.21039673]
#  [0.80300487 0.19699513]
#  [0.78941049 0.21058951]
#  [0.31372357 0.68627643]]
# 565    0
# 160    0
# 553    1
# 860    0
# 241    1
# Name: Survived, dtype: int64

# %% [markdown]
# ---
# # Summary
#
# * The Voting Classifier composed of four classifiers that were tuned with cross-validated grid search and glued together via *soft-voting* (i.e. using weighted some of the predicted probabilities) is my best bet.
#
# * It is able to assign probability of survival to any record (i.e. passanger).
#
# * We will test it in the next notebook.

# %% [markdown]
# ---
# ### End
